# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("http://cowid.netlify.com/data/full_data.csv")

# %%
link2 = "https://docs.google.com/spreadsheets/d/1avGWWl1J19O_Zm0NGTGy2E-fOG05i4ljRfjl87P7FiA/export?format=csv&gid=0"
df2 = pd.read_csv(link2)

# %%
max(df2.Date)
# Out:
# '2020-03-13'

# %%
max(df.date)
# Out:
# '2020-03-14'

# %% [markdown]
# China : 2020-02-05 	China 	3892.0 1.155294

# %%
df['ratio'] = df.total_deaths / df.total_deaths.shift(1)
df['ratio2'] = df.total_cases / df.total_cases.shift(1)

# %%
country = 'Australia'
n = 10

fig, ax1 = plt.subplots(figsize=(20,10))

t = df[df['location']==country][df['total_cases'] > n]['date'].iloc[1:]
data1 = df[df['location']==country][df['total_cases'] > n]['new_cases'].iloc[1:]
data2 = df[df['location']==country][df['total_cases'] > n]['ratio'].iloc[1:]

color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('new cases', color=color)
ax1.plot(t, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('DoD total cases ratio', color=color)  # we already handled the x-label with ax1
ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
df[df['location']==country][df['total_cases']>n]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#            date   location  new_cases  new_deaths  total_cases  total_deaths  \
# 87   2020-02-01  Australia        3.0         NaN           12           NaN
# 88   2020-02-02  Australia        0.0         NaN           12           NaN
# 89   2020-02-03  Australia        0.0         NaN           12           NaN
# 90   2020-02-04  Australia        0.0         NaN           12           NaN
# 91   2020-02-05  Australia        1.0         NaN           13           NaN
# 92   2020-02-06  Australia        1.0         NaN           14           NaN
# 93   2020-02-07  Australia        1.0         NaN           15           NaN
# 94   2020-02-08  Australia        0.0         NaN           15           NaN
# 95   2020-02-09  Australia        0.0         NaN           15           NaN
# 96   2020-02-10  Australia        0.0         NaN           15           NaN
# 97   2020-02-11  Australia        0.0         NaN           15           NaN
# 98   2020-02-12  Australia        0.0         NaN           15           NaN
# 99   2020-02-13  Australia        0.0         NaN           15           NaN
# 100  2020-02-14  Australia        0.0         NaN           15           NaN
# 101  2020-02-15  Australia        0.0         NaN           15           NaN
# 102  2020-02-16  Australia        0.0         NaN           15           NaN
# 103  2020-02-17  Australia        0.0         NaN           15           NaN
# 104  2020-02-18  Australia        0.0         NaN           15           NaN
# 105  2020-02-19  Australia        0.0         NaN           15           NaN
# 106  2020-02-20  Australia        0.0         NaN           15           NaN
# 107  2020-02-21  Australia        2.0         NaN           17           NaN
# 108  2020-02-22  Australia        4.0         NaN           21           NaN
# 109  2020-02-23  Australia        1.0         NaN           22           NaN
# 110  2020-02-24  Australia        0.0         NaN           22           NaN
# 111  2020-02-25  Australia        0.0         NaN           22           NaN
# 112  2020-02-26  Australia        1.0         NaN           23           NaN
# 113  2020-02-27  Australia        0.0         NaN           23           NaN
# 114  2020-02-28  Australia        0.0         NaN           23           NaN
# 115  2020-02-29  Australia        1.0         NaN           24           NaN
# 116  2020-03-01  Australia        1.0         NaN           25           NaN
# 117  2020-03-02  Australia        2.0         NaN           27           1.0
# 118  2020-03-03  Australia        6.0         0.0           33           1.0
# 119  2020-03-04  Australia       10.0         0.0           43           1.0
# 120  2020-03-05  Australia       14.0         0.0           57           1.0
# 121  2020-03-06  Australia        0.0         1.0           57           2.0
# 122  2020-03-07  Australia        5.0         0.0           62           2.0
# 123  2020-03-08  Australia       12.0         1.0           74           3.0
# 124  2020-03-09  Australia        3.0         0.0           77           3.0
# 125  2020-03-10  Australia       15.0         0.0           92           3.0
# 126  2020-03-11  Australia       20.0         0.0          112           3.0
# 127  2020-03-12  Australia       10.0         0.0          122           3.0
# 128  2020-03-13  Australia       18.0         0.0          140           3.0
# 129  2020-03-14  Australia       57.0         0.0          197           3.0
#
#      ratio    ratio2
# 87     NaN  1.333333
# 88     NaN  1.000000
# 89     NaN  1.000000
# 90     NaN  1.000000
# 91     NaN  1.083333
# 92     NaN  1.076923
# 93     NaN  1.071429
# 94     NaN  1.000000
# 95     NaN  1.000000
# 96     NaN  1.000000
# 97     NaN  1.000000
# 98     NaN  1.000000
# 99     NaN  1.000000
# 100    NaN  1.000000
# 101    NaN  1.000000
# 102    NaN  1.000000
# 103    NaN  1.000000
# 104    NaN  1.000000
# 105    NaN  1.000000
# 106    NaN  1.000000
# 107    NaN  1.133333
# 108    NaN  1.235294
# 109    NaN  1.047619
# 110    NaN  1.000000
# 111    NaN  1.000000
# 112    NaN  1.045455
# 113    NaN  1.000000
# 114    NaN  1.000000
# 115    NaN  1.043478
# 116    NaN  1.041667
# 117    NaN  1.080000
# 118    1.0  1.222222
# 119    1.0  1.303030
# 120    1.0  1.325581
# 121    2.0  1.000000
# 122    1.0  1.087719
# 123    1.5  1.193548
# 124    1.0  1.040541
# 125    1.0  1.194805
# 126    1.0  1.217391
# 127    1.0  1.089286
# 128    1.0  1.147541
# 129    1.0  1.407143
